# %% [markdown]
# Setup
# -----

# %%
import numpy as np
from numpy import *
from scipy import interpolate
import os
import csv
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from matplotlib.pyplot import *
from matplotlib.cm import Blues_r, Blues, gist_heat, hot, bone
from matplotlib import pylab
set_cmap('hot')
pylab.rcParams['figure.figsize'] = 10, 10
# %matplotlib inline

# %% [markdown]
# Parameter Ranges
# ----------------

# %%
param_ranges = {
    'stop_on_mass': 4000,
    'stop_on_time': 20000,
    'boundary_layer': 5,
    'light_penetration': (0.1, 32),
    'tension_power': (0.1, 4),
    'distance_power': (0.1, 4),
    'initial_cell_spacing': 2,
    'media_ratio': (0.01, 1.2),
    'media_monod': (0.01, 1),
    'light_monod': (0.01, 1)
}

param_features = []
for param, r in param_ranges.iteritems():
    if isinstance(r, tuple):
        param_features.append(param)

# %% [markdown]
# Load Results
# ------------

# %%
features = []
values = []
for name in os.listdir('dump'):
    with open('dump/'+name, 'r') as csv_file:
        for row in csv.DictReader(csv_file):
            features.append([float(row[param]) for param in param_features])
            values.append(float(row['hsa']))

features = np.array(features, dtype=float)
values = np.array(values, dtype=float)

# %%
def regress_scikit(features, values):
    reg = LinearRegression()
    reg.fit(features, values, n_jobs=-1)
    print 'Coefficients'
    print '------------'
    for param, coeff in zip(param_features, reg.coef_):
        print '  ', param + ':', coeff
    print '------------'
    print 'Intercept:', reg.intercept_
    print 'R^2:', reg.score(features, values)
    
def regress_sm(features, values):
    features = sm.add_constant(features, prepend=False)
    model = sm.OLS(values, features)
    model.exog_names[:-1] = param_features
    result = model.fit()
    print result.summary()

# %% [markdown]
# Linear Regression
# =================

# %%
regress_sm(features, values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.599
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                 5.903e+04
# Date:                Wed, 25 Jun 2014   Prob (F-statistic):               0.00
# Time:                        17:03:22   Log-Likelihood:            -2.9865e+05
# No. Observations:              237118   AIC:                         5.973e+05
# Df Residuals:                  237111   BIC:                         5.974e+05
# Df Model:                           6
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# light_monod          -0.0967      0.006    -15.774      0.000        -0.109    -0.085
# media_ratio           1.3113      0.005    257.526      0.000         1.301     1.321
# tension_power        -0.8062      0.002   -517.975      0.000        -0.809    -0.803
# media_monod           0.0502      0.006      8.183      0.000         0.038     0.062
# distance_power        0.1468      0.002     94.530      0.000         0.144     0.150
# light_penetration     0.0189      0.000     99.344      0.000         0.019     0.019
# const                 1.4852      0.008    190.560      0.000         1.470     1.500
# ==============================================================================
# Omnibus:                     3422.226   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3571.813
# Skew:                           0.299   Prob(JB):                         0.00
# Kurtosis:                       3.069   Cond. No.                         94.5
# ==============================================================================

# %% [markdown]
# High light penetration regression
# ---------------------------------
# p > 6

# %%
high_light = features[:,-1] > 6
regress_sm(features[high_light, :], values[high_light])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                 5.591e+04
# Date:                Wed, 25 Jun 2014   Prob (F-statistic):               0.00
# Time:                        17:03:43   Log-Likelihood:            -2.2341e+05
# No. Observations:              185605   AIC:                         4.468e+05
# Df Residuals:                  185598   BIC:                         4.469e+05
# Df Model:                           6
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# light_monod          -0.0284      0.007     -4.333      0.000        -0.041    -0.016
# media_ratio           1.3423      0.005    246.807      0.000         1.332     1.353
# tension_power        -0.8565      0.002   -515.152      0.000        -0.860    -0.853
# media_monod           0.0567      0.007      8.644      0.000         0.044     0.070
# distance_power        0.1545      0.002     93.137      0.000         0.151     0.158
# light_penetration     0.0009      0.000      3.368      0.001         0.000     0.001
# const                 1.9048      0.009    208.377      0.000         1.887     1.923
# ==============================================================================
# Omnibus:                     2239.785   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2248.491
# Skew:                           0.254   Prob(JB):                         0.00
# Kurtosis:                       2.820   Cond. No.                         112.
# ==============================================================================

# %% [markdown]
# High light penetration and uptake ratio regression
# ---------------------------------
# p > 6 and r > 0.8

# %%
high_light_and_media = (features[:,-1] > 6) & (features[:, 1] > 0.8)
regress_sm(features[high_light_and_media, :], values[high_light_and_media])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                 2.309e+04
# Date:                Wed, 25 Jun 2014   Prob (F-statistic):               0.00
# Time:                        17:03:46   Log-Likelihood:                -75095.
# No. Observations:               62667   AIC:                         1.502e+05
# Df Residuals:                   62660   BIC:                         1.503e+05
# Df Model:                           6
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# light_monod          -0.0253      0.011     -2.251      0.024        -0.047    -0.003
# media_ratio           0.2430      0.028      8.735      0.000         0.188     0.297
# tension_power        -1.0457      0.003   -366.864      0.000        -1.051    -1.040
# media_monod          -0.1912      0.011    -17.072      0.000        -0.213    -0.169
# distance_power        0.1755      0.003     61.666      0.000         0.170     0.181
# light_penetration    -0.0013      0.000     -2.894      0.004        -0.002    -0.000
# const                 3.3894      0.031    107.800      0.000         3.328     3.451
# ==============================================================================
# Omnibus:                      687.185   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              429.581
# Skew:                           0.014   Prob(JB):                     5.22e-94
# Kurtosis:                       2.595   Cond. No.                         262.
# ==============================================================================

# %% [markdown]
# H distribution
# ==============

# %%
hist(values, bins=30);

# %%
hist(values[values > 2], bins=30);

# %%
def plot_phase(x, y, z, num_cells=10, **plot_args):
    x_min, x_max = x.min(), x.max()
    y_min, y_max = y.min(), y.max()
    
    try:
        num_x, num_y = num_cells
    except TypeError:
        num_x, num_y = num_cells, num_cells
    
    x_grid, y_grid = np.mgrid[x_min:x_max:num_x*1j,
                              y_min:y_max:num_y*1j]
            
    z_sum = np.histogram2d(x, y, num_cells, weights=z)[0]
    z_count = np.histogram2d(x, y, num_cells)[0]
    z_count[z_count == 0] = 1
    z_grid = z_sum/z_count
    
    pcolormesh(x_grid, y_grid, z_grid, **plot_args)
    xlim(x_min, x_max)
    ylim(y_min, y_max)

# %% [markdown]
# Parameter Comparisons
# =====================

# %% [markdown]
# Absolute H value
# ----------------

# %%
n = len(param_features)
#v_min, v_max = values.min(), values.max()
v_min = 0
v_max = 3 # averaging brings most values down

for i, param1 in enumerate(param_features):
    for j, param2 in enumerate(param_features):
        subplot(n, n, i*n + j + 1)
        plot_phase(features[:, j], features[:, i], values,
                   vmin=v_min, vmax=v_max, cmap=Blues)
        
        tick_params(which='both', bottom='off', top='off', left='off', 
                    right='off', labelbottom='off', labelleft='off')
        if j == 0: ylabel(param1)
        if i == n-1: xlabel(param2)
gcf().set_size_inches(10,10)
savefig('plots/images/param_space_absoulte.png', dpi=300)
show()

# %% [markdown]
# Relative H values
# -----------------

# %%
for i, param1 in enumerate(param_features):
    for j, param2 in enumerate(param_features):
        subplot(n, n, i*n + j + 1)
        plot_phase(features[:, j], features[:, i], values, cmap=Blues)
        
        tick_params(which='both', bottom='off', top='off', left='off', 
                    right='off', labelbottom='off', labelleft='off')
        if j == 0: ylabel(param1)
        if i == n-1:  xlabel(param2)
gcf().set_size_inches(10,10)
savefig('plots/images/param_space_relative.png', dpi=300)
show()

# %% [markdown]
# Absolute H, No Tension Power
# ==========================

# %%
param_ranges = {
    'stop_on_mass': 4000,
    'stop_on_time': 20000,
    'boundary_layer': 5,
    'light_penetration': (0.1, 32),
    'distance_power': (0.1, 4),
    'initial_cell_spacing': 2,
    'media_ratio': (0.01, 1.2),
    'media_monod': (0.01, 1),
    'light_monod': (0.01, 1)
}

param_features = []
for param, r in param_ranges.iteritems():
    if isinstance(r, tuple):
        param_features.append(param)
        
features = []
values = []
for name in os.listdir('dump'):
    with open('dump/'+name, 'r') as csv_file:
        for row in csv.DictReader(csv_file):
            features.append([float(row[param]) for param in param_features])
            values.append(float(row['hsa']))

features = np.array(features, dtype=float)
values = np.array(values, dtype=float)

# %%
n = len(param_features)
#v_min, v_max = values.min(), values.max()
v_min = 0
v_max = 2 # averaging brings most values down

for i, param1 in enumerate(param_features):
    for j, param2 in enumerate(param_features):
        subplot(n, n, i*n + j + 1)
        plot_phase(features[:, j], features[:, i], values,
                   vmin=v_min, vmax=v_max, cmap=Blues)
        
        tick_params(which='both', bottom='off', top='off', left='off', 
                    right='off', labelbottom='off', labelleft='off')
        if j == 0: ylabel(param1)
        if i == n-1: xlabel(param2)
gcf().set_size_inches(10,10)
savefig('plots/images/param_space_absoulte.png', dpi=300)
show()
